# %%
#!pip install datadotworld
#!pip install datadotworld[pandas]

# %%
#!dw configure

# %%
from google.colab import drive

# %%
import pandas as pd

# %%
import numpy as np

# %%
import datadotworld as dw

# %%
#drive.mount("/content/drive")

# %%
ls
# Out:
# drive/  sample_data/

# %%
cd "drive/My Drive/Colab Notebooks/dw_matrix"
# Out:
# /content/drive/My Drive/Colab Notebooks/dw_matrix

# %%
# !mkdir data

# %%
# !echo 'data' > .gitignore

# %%
# !git add .gitignore

# %%
data = dw.load_dataset('datafiniti/mens-shoe-prices')

# %%
df = data.dataframes['7004_1']
df.shape
# Out:
# (19387, 48)

# %%
df.sample(5)
# Out:
#                          id asins           brand  ...  vin websiteids  weight
# 2423   AVpe8UD1ilAPnD_xRZ2B   NaN            PUMA  ...  NaN        NaN     NaN
# 13847  AVpfvt2Q1cnluZ0-qgsi   NaN     New Balance  ...  NaN        NaN     NaN
# 18351  AVpfjjJXLJeJML43_V5q   NaN       Twisted X  ...  NaN        NaN     NaN
# 13443  AVpfgVL8ilAPnD_xc8aH   NaN           Rocky  ...  NaN        NaN     NaN
# 13886  AVpf21VHLJeJML43E_Zq   NaN  Tommy Hilfiger  ...  NaN        NaN     NaN
#
# [5 rows x 48 columns]

# %%
df.columns
# Out:
# Index(['id', 'asins', 'brand', 'categories', 'colors', 'count', 'dateadded',
#        'dateupdated', 'descriptions', 'dimension', 'ean', 'features',
#        'flavors', 'imageurls', 'isbn', 'keys', 'manufacturer',
#        'manufacturernumber', 'merchants', 'name', 'prices_amountmin',
#        'prices_amountmax', 'prices_availability', 'prices_color',
#        'prices_condition', 'prices_count', 'prices_currency',
#        'prices_dateadded', 'prices_dateseen', 'prices_flavor', 'prices_issale',
#        'prices_merchant', 'prices_offer', 'prices_returnpolicy',
#        'prices_shipping', 'prices_size', 'prices_source', 'prices_sourceurls',
#        'prices_warranty', 'quantities', 'reviews', 'sizes', 'skus',
#        'sourceurls', 'upc', 'vin', 'websiteids', 'weight'],
#       dtype='object')

# %%
df.prices_currency.unique()
# Out:
# array(['USD', 'AUD', 'CAD', 'EUR', nan, 'GBP', 'New with box',
#        'UnbeatableSale.com, Inc. - Walmart.com',
#        'PalmBeach Jewelry - Walmart.com', 'new', 'New without tags',
#        'SHOEBACCA LTD. - Walmart.com', 'Shoes.com',
#        'Wholesale Costume and Party Supplies - Walmart.com'], dtype=object)

# %%
df.prices_currency.value_counts()
# Out:
# USD                                                   18524
# AUD                                                     338
# CAD                                                     303
# EUR                                                     107
# GBP                                                      22
# UnbeatableSale.com, Inc. - Walmart.com                    3
# new                                                       3
# New with box                                              3
# PalmBeach Jewelry - Walmart.com                           3
# Wholesale Costume and Party Supplies - Walmart.com        2
# SHOEBACCA LTD. - Walmart.com                              1
# Shoes.com                                                 1
# New without tags                                          1
# Name: prices_currency, dtype: int64

# %%
df.prices_currency.value_counts(normalize=True)
# Out:
# USD                                                   0.959246
# AUD                                                   0.017503
# CAD                                                   0.015691
# EUR                                                   0.005541
# GBP                                                   0.001139
# UnbeatableSale.com, Inc. - Walmart.com                0.000155
# new                                                   0.000155
# New with box                                          0.000155
# PalmBeach Jewelry - Walmart.com                       0.000155
# Wholesale Costume and Party Supplies - Walmart.com    0.000104
# SHOEBACCA LTD. - Walmart.com                          0.000052
# Shoes.com                                             0.000052
# New without tags                                      0.000052
# Name: prices_currency, dtype: float64

# %%
df_usd=df[df.prices_currency=='USD'].copy()
df_usd.shape
# Out:
# (18524, 48)

# %%
df_usd.prices_amountmin.head()
# Out:
# 0    39.89
# 1    51.99
# 2    40.02
# 3    50.31
# 4    46.26
# Name: prices_amountmin, dtype: object

# %%
df_usd['prices_amountmin'] = df_usd.prices_amountmin.astype(np.float)
df_usd['prices_amountmin'].hist()

# %%
np.percentile(df_usd['prices_amountmin'],99)
# Out:
# 895.0

# %%
filter_max = np.percentile(df_usd['prices_amountmin'],99)
filter_max
# Out:
# 895.0

# %%
df_usd_filter = df_usd[df_usd['prices_amountmin']<filter_max]

# %%
  df_usd_filter.prices_amountmin.hist(bins=100)

# %%
df.to_csv('data/shoes_prices.csv', index=False)

# %%
ls matrix_one
# Out:
# Day_3.ipynb  HelloGithub.ipynb

# %%
# !git add matrix_one/Day_3.ipynb

# %%
# !git commit -m "Read Men's Shoe Prices dataset from data.world"
# Out:
# [master b3360a2] Read Men's Shoe Prices dataset from data.world
#  2 files changed, 2 insertions(+), 129 deletions(-)
#  rewrite .gitignore (100%)
#  create mode 100644 matrix_one/Day_3.ipynb

# %%
# !git config --global user.email "jobo91@poczta.onet.pl"
# !git config --global user.name "Joanna"

# %%
# !git push -u origin master
# Out:
# Counting objects: 5, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (3/3), done.
# Writing objects: 100% (5/5), 20.72 KiB | 4.14 MiB/s, done.
# Total 5 (delta 0), reused 0 (delta 0)
# To https://github.com/Ponpom/dw_matrix.git
#    55fa84b..b3360a2  master -> master
# Branch 'master' set up to track remote branch 'master' from 'origin'.
